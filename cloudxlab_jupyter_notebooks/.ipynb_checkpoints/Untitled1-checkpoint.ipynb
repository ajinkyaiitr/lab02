# %%
import numpy as np

# %%
import numpy as np
import pandas as pd

# %%
features = ['quality','marketing_strategy','marketing_team','automation','social_presence','financial_status','sales']

# %%
length = 50000
values = [np.random.randint(1,10,size = length),np.random.randint(1,50,size = length),np.random.randint(1,50,size = length),
          np.random.randint(1,10,size = length),np.random.randint(1,10,size = length),np.random.randint(1,100,size = length),
          np.random.randint(10000,500000,size = length)]

# %%
data = pd.DataFrame(dict(zip(features,values)))
data
# Out:
#        quality  marketing_strategy  marketing_team  automation  \
# 0            7                  45              32           2
# 1            8                  14               2           3
# 2            4                  49               2           5
# 3            6                   6              31           4
# 4            4                  48              27           3
# ...        ...                 ...             ...         ...
# 49995        2                   8              38           6
# 49996        8                   6              24           4
# 49997        6                  31              48           4
# 49998        5                   2              35           6
# 49999        8                  27              22           5
#
#        social_presence  financial_status   sales
# 0                    1                58  470295
# 1                    6                86   25106
# 2                    3                83  117819
# ...

# %%
X = data.drop(['sales'],axis = 1)

# %%
X
# Out:
#        quality  marketing_strategy  marketing_team  automation  \
# 0            7                  45              32           2
# 1            8                  14               2           3
# 2            4                  49               2           5
# 3            6                   6              31           4
# 4            4                  48              27           3
# ...        ...                 ...             ...         ...
# 49995        2                   8              38           6
# 49996        8                   6              24           4
# 49997        6                  31              48           4
# 49998        5                   2              35           6
# 49999        8                  27              22           5
#
#        social_presence  financial_status
# 0                    1                58
# 1                    6                86
# 2                    3                83
# 3                    4                51
# ...

# %%
y_a = data['sales']

# %%
y_a
# Out:
# 0        470295
# 1         25106
# 2        117819
# 3        383061
# 4         42747
#           ...
# 49995    168337
# 49996    180299
# 49997    438060
# 49998    126830
# 49999    133926
# Name: sales, Length: 50000, dtype: int64

# %%
f = len(features)-1
M = np.random.randn(f,1)

# %%
###Functions to be used
#1.line
#2.Error
#3.gradient_m
#4.gradient_c
#####
###Line Function
def line(m,x,c):
    return np.dot(x,m) + c
print(line(M,X,10).shape)
def error(m,x,c,y_a):
    y_p = line(m,x,c)
    return np.mean((y_p - y_a) **2)
print(error(M,X,10,y_a).shape)
# Out:
# (50000, 1)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-24-58724223e76b> in <module>
#      12     y_p = line(m,x,c)
#      13     return np.mean((y_p - y_a) **2)
# ---> 14 print(error(M,X,10,y_a).shape)
#
# <ipython-input-24-58724223e76b> in error(m, x, c, y_a)
#      11 def error(m,x,c,y_a):
#      12     y_p = line(m,x,c)
# ---> 13     return np.mean((y_p - y_a) **2)
#      14 print(error(M,X,10,y_a).shape)
#
# /usr/local/anaconda/lib/python3.6/site-packages/pandas/core/series.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     808         # for binary ops, use our custom dunder methods
#     809         result = ops.maybe_dispatch_ufunc_to_dunder_op(
# --> 810             self, ufunc, method, *inputs, **kwargs
#     811         )
#     812         if result is not NotImplemented:
#
# ...
